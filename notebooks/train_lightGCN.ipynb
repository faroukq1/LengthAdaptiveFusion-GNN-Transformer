# %%
! git clone https://github.com/faroukq1/LightGCN-MODED.git
# Out:
# Cloning into 'LightGCN-MODED'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 104 (delta 3), reused 17 (delta 3), pack-reused 85 (from 1)
# Receiving objects: 100% (104/104), 56.87 MiB | 23.08 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Updating files: 100% (64/64), done.

# %%
# %%bash
# cd /kaggle/working/LightGCN-MODED/
#
# python LightGCN.py \
#   --dataset ml-1m \
#   --regs "[1e-4]" \
#   --embed_size 64 \
#   --layer_size "[64,64,64]" \
#   --lr 0.001 \
#   --batch_size 2048 \
#   --epoch 1000 \
#   --Ks "[20]" \
#   --verbose 10
# Out:
# eval_score_matrix_foldout with cpp
# n_users=6038, n_items=3533
# n_interactions=575281
# n_train=569244, n_test=6037, sparsity=0.02697
# already load adj matrix (9571, 9571) 0.12224507331848145
# use the pre adjcency matrix
# using random initialization
# without pretraining.
# Epoch 10 [15.4s]: train==[0.26975=0.26893 + 0.00083]
# Epoch 20: train==[0.21244=0.21068 + 0.00176 + 0.00000], recall=[0.13278], precision=[0.40833], ndcg=[0.44215]
# Epoch 20 [34.6s + 0.5s]: test==[0.33643=0.33464 + 0.00179 + 0.00000], recall=[0.08730], precision=[0.00436], ndcg=[0.03413]
# Epoch 30 [15.4s]: train==[0.17655=0.17400 + 0.00256]
# Epoch 40: train==[0.15674=0.15352 + 0.00323 + 0.00000], recall=[0.16794], precision=[0.48254], ndcg=[0.52463]
# Epoch 40 [33.1s + 0.4s]: test==[0.28428=0.28098 + 0.00331 + 0.00000], recall=[0.10552], precision=[0.00528], ndcg=[0.04179]
# Epoch 50 [15.8s]: train==[0.13938=0.13551 + 0.00388]
# ...
