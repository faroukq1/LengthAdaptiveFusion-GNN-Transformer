# %%
# !git clone https://github.com/faroukq1/SASRec-MODED
# Out:
# Cloning into 'SASRec-MODED'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (686/686), done.
# remote: Compressing objects: 100% (597/597), done.
# remote: Total 768 (delta 113), reused 631 (delta 77), pack-reused 82 (from 1)
# Receiving objects: 100% (768/768), 21.90 MiB | 23.24 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %%
# !cd /kaggle/working/SASRec-MODED/python && \
python main.py \
    --dataset=ml-1m \
    --train_dir=default \
    --maxlen=200 \
    --dropout_rate=0.2 \
    --device=cuda \
    --num_epochs=200 \
    --batch_size=128 \
    --lr=0.001 \
    --hidden_units=50 \
    --num_blocks=2 \
    --num_heads=1
# Out:
# average sequence length: 163.50
# loss in epoch 1 iteration 0: 1.3896503448486328
# loss in epoch 1 iteration 1: 1.384190559387207
# loss in epoch 1 iteration 2: 1.3780517578125
# loss in epoch 1 iteration 3: 1.3671138286590576
# loss in epoch 1 iteration 4: 1.356537938117981
# loss in epoch 1 iteration 5: 1.344709038734436
# loss in epoch 1 iteration 6: 1.333351969718933
# loss in epoch 1 iteration 7: 1.318877935409546
# loss in epoch 1 iteration 8: 1.308330774307251
# loss in epoch 1 iteration 9: 1.2939196825027466
# loss in epoch 1 iteration 10: 1.2815492153167725
# loss in epoch 1 iteration 11: 1.269803524017334
# loss in epoch 1 iteration 12: 1.2567713260650635
# loss in epoch 1 iteration 13: 1.2411839962005615
# loss in epoch 1 iteration 14: 1.225947380065918
# loss in epoch 1 iteration 15: 1.2276922464370728
# loss in epoch 1 iteration 16: 1.2114660739898682
# loss in epoch 1 iteration 17: 1.1948418617248535
# loss in epoch 1 iteration 18: 1.1787731647491455
# ...
